# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
insurance_filepath="D:/vscode/vscode_python/data_visualization/data/insurance.csv"
insurance_data=pd.read_csv(insurance_filepath)

# %%
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # 散点图

# %%
sns.scatterplot(x=insurance_data["bmi"],y=insurance_data["charges"])
"""括号内是给横纵坐标添加名称"""
# Out:
# '括号内是给横纵坐标添加名称'

# %% [markdown]
# # 添加回归线

# %%
sns.regplot(x=insurance_data["bmi"],y=insurance_data["charges"])
"""使用函数regplot添加回归线"""
# Out:
# '使用函数regplot添加回归线'

# %% [markdown]
# # 颜色编码散点图

# %%
"""可以用散点图显示三个变量的关系，对点进行颜色编码"""
sns.scatterplot(x=insurance_data["bmi"],y=insurance_data["charges"],hue=insurance_data["smoker"])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
"""使用lmplot函数给这个添加2条回归线"""
sns.lmplot(x="bmi",y="charges",hue="smoker",data=insurance_data)
"""与先前不一样,由x=insurance_data["bmi"]变为了x="bmi"."""
# Out:
# '与先前不一样,由x=insurance_data["bmi"]变为了x="bmi".'

# %%
#另一类散点图，以一个变量为主轴，如"smoke"

# %%
sns.swarmplot(x=insurance_data["smoker"],y=insurance_data["charges"])
# Out:
# D:\python\anaconda_software\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 37.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='smoker', ylabel='charges'>
# D:\python\anaconda_software\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 60.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
